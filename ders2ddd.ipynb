# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
def compare_list_ndarray():
    #numpy as np
    list_1=[1,"2asdasdasd,3",'4',5,6] #broadcast
    list_2=[1,"2asdasdaasdasdsd,3",'42323',35,64]
    print(list_1+list_2)

    list_1=[1,2,3,4] #broadcast
    list_2=[1,2,3,4]
    print(list_1+list_2+[10])

    list_3=np.asarray([1,2,3,4]) #adarray  asarray
    list_4=np.asarray([1,2,3,4])
    print(list_3+list_4+10)
def get_jpeg_files():
    os.getcwd()
    os.listdir()
    path=os.getcwd()
    jpg_files=[f for f in os.listdir(path) if f.endswith('.jpg')]
    return jpg_files
get_jpeg_files()
compare_list_ndarray()   
get_jpeg_files()
# Out:
# [1, '2asdasdasd,3', '4', 5, 6, 1, '2asdasdaasdasdsd,3', '42323', 35, 64]
# [1, 2, 3, 4, 1, 2, 3, 4, 10]
# [12 14 16 18]
# ['ders1.jpg', 'pic_1.jpg']

# %%
def display_two_image(im_1,im_2):
    plt.subplot(1,2,1)
    plt.imshow(image_1)

    plt.subplot(1,2,2)
    plt.imshow(image_2+150)

    plt.show
def rotate(im_1):
    
    m,n,k=im_1.shape
    new_image=np.zeros((n,m,k),dtype='uint8')
    for i in range(m):
        for j in range(n):
            temp_1=image_1[i,j]
            new_image[j,i]=temp_1
            
    return new_image

# %%
image_1=plt.imread('pic_1.jpg')
image_2=rotate(image_1)
display_two_image(image_1,image_2)

# %%
image_1
# Out:
# array([[[ 41, 109, 180],
#         [ 41, 109, 180],
#         [ 42, 110, 181],
#         ...,
#         [ 24,  96, 168],
#         [ 23,  95, 167],
#         [ 22,  94, 166]],
#
#        [[ 40, 110, 180],
#         [ 40, 110, 180],
#         [ 41, 111, 181],
#         ...,
#         [ 24,  96, 168],
#         [ 24,  96, 168],
#         [ 23,  95, 167]],
#
#        [[ 40, 110, 182],
#         [ 41, 111, 183],
#         [ 41, 111, 181],
#         ...,
#         [ 25,  97, 169],
#         [ 24,  96, 168],
#         [ 23,  95, 167]],
#
#        ...,
#
#        [[  0,  10,  11],
#         [  0,  10,  11],
#         [  2,  12,  13],
#         ...,
#         [ 43,  60,  54],
#         [ 40,  55,  50],
#         [ 36,  51,  48]],
#
#        [[  0,   5,   7],
#         [  0,   4,   6],
#         [  0,   4,   6],
#         ...,
#         [ 29,  44,  39],
#         [ 14,  29,  26],
#         [ 27,  39,  37]],
#
#        [[  0,   5,   7],
#         [  0,   4,   6],
#         [  0,   4,   6],
# ...

# %%
type(image_1),image_1.ndim
# Out:
# (numpy.ndarray, 3)

# %%
m,n,k=image_1.shape
m,n,k
# Out:
# (410, 731, 3)

# %%
t_1=10

# %%
for i in range(t_1):
    for j in range(t_1):
        temp_1=image_1[i,j]
        print(temp_1[2],end=" ")

# %%
image_2=image_1-30
image_1.shape, image_2.shape
image_1[25,300,:],image_2[25,300,:]
# %matplotlib inline
plt.imshow(image_1)
plt.show
plt.imshow(image_2)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
im_1.ndim
type(im_1)
# Out:
# numpy.ndarray

# %%
my_image_1[i,j,k]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-204-7217c97f18ce> in <module>
# ----> 1 my_image_1[i,j,k]
#
# NameError: name 'my_image_1' is not defined

# %%
im_1[10,10,2]
# Out:
# 185

# %%
def my_display_two_image(im_1,im_2):
    plt.subplot(1,2,1)
    plt.imshow(image_1)

    plt.subplot(1,2,2)
    plt.imshow(image_2+150)

    plt.show
def my_rotate(im_1):
    m,n,k=im_1.shape
    new_image=np.zeros((n,m,k),dtype='uint8')
    for i in range(m):
        for j in range(n):
            temp_1=image_1[i,j]
            new_image[j,i]=temp
            
    return new_image

my_display_two_image(image_1,new_image)

# %%
# Out:
#   File "<ipython-input-205-58351ad48164>", line 2
#     m,n,k=im_1.shape
#     ^
# IndentationError: expected an indented block

# %%
plt.subplot(1,2,1)
plt.imshow(image_1)

plt.subplot(1,2,2)
plt.imshow(new_image)

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
