# %%
list_1=[1,'2',3,4,5]

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
image_1=plt.imread('/Users/murat/pic_1.jpg')

# %%
plt.imshow(image_1)

# %%
plt.show()

# %%
image_1
# x y
#pixel, 400x600 resolution ,dpi
# Out:
# array([[[ 41, 109, 180],
#         [ 41, 109, 180],
#         [ 42, 110, 181],
#         ...,
#         [ 24,  96, 168],
#         [ 23,  95, 167],
#         [ 22,  94, 166]],
#
#        [[ 40, 110, 180],
#         [ 40, 110, 180],
#         [ 41, 111, 181],
#         ...,
#         [ 24,  96, 168],
#         [ 24,  96, 168],
#         [ 23,  95, 167]],
#
#        [[ 40, 110, 182],
#         [ 41, 111, 183],
#         [ 41, 111, 181],
#         ...,
#         [ 25,  97, 169],
#         [ 24,  96, 168],
#         [ 23,  95, 167]],
#
#        ...,
#
#        [[  0,  10,  11],
#         [  0,  10,  11],
#         [  2,  12,  13],
#         ...,
#         [ 43,  60,  54],
#         [ 40,  55,  50],
#         [ 36,  51,  48]],
#
#        [[  0,   5,   7],
#         [  0,   4,   6],
#         [  0,   4,   6],
#         ...,
#         [ 29,  44,  39],
#         [ 14,  29,  26],
#         [ 27,  39,  37]],
#
#        [[  0,   5,   7],
#         [  0,   4,   6],
#         [  0,   4,   6],
# ...

# %%
type(image_1)
# Out:
# numpy.ndarray

# %%
image_1.shape
# Out:
# (410, 731, 3)

# %%
for row in range(168):
    for cow in range (300):
        print(image_1[row,cow,0],[row,cow,1],[row,cow,2])#rgb ,pixel,intensity
# Out:
# 41 [0, 0, 1] [0, 0, 2]
# 41 [0, 1, 1] [0, 1, 2]
# 42 [0, 2, 1] [0, 2, 2]
# 43 [0, 3, 1] [0, 3, 2]
# 43 [0, 4, 1] [0, 4, 2]
# 44 [0, 5, 1] [0, 5, 2]
# 46 [0, 6, 1] [0, 6, 2]
# 46 [0, 7, 1] [0, 7, 2]
# 47 [0, 8, 1] [0, 8, 2]
# 49 [0, 9, 1] [0, 9, 2]
# 49 [0, 10, 1] [0, 10, 2]
# 50 [0, 11, 1] [0, 11, 2]
# 50 [0, 12, 1] [0, 12, 2]
# 52 [0, 13, 1] [0, 13, 2]
# 52 [0, 14, 1] [0, 14, 2]
# 52 [0, 15, 1] [0, 15, 2]
# 58 [0, 16, 1] [0, 16, 2]
# 58 [0, 17, 1] [0, 17, 2]
# 59 [0, 18, 1] [0, 18, 2]
# 58 [0, 19, 1] [0, 19, 2]
# 57 [0, 20, 1] [0, 20, 2]
# 58 [0, 21, 1] [0, 21, 2]
# 58 [0, 22, 1] [0, 22, 2]
# 56 [0, 23, 1] [0, 23, 2]
# 54 [0, 24, 1] [0, 24, 2]
# 51 [0, 25, 1] [0, 25, 2]
# 51 [0, 26, 1] [0, 26, 2]
# 49 [0, 27, 1] [0, 27, 2]
# 48 [0, 28, 1] [0, 28, 2]
# 49 [0, 29, 1] [0, 29, 2]
# 49 [0, 30, 1] [0, 30, 2]
# 48 [0, 31, 1] [0, 31, 2]
# 46 [0, 32, 1] [0, 32, 2]
# 46 [0, 33, 1] [0, 33, 2]
# 46 [0, 34, 1] [0, 34, 2]
# 47 [0, 35, 1] [0, 35, 2]
# 47 [0, 36, 1] [0, 36, 2]
# ...
